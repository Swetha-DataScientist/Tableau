# %% [markdown]
# # Tableau project

# %% [markdown]
# Tableau is a very smart software, which is used for data visualization. Information of an entire dataset can be represented for visualization with the help of the amazing features in Tableau. In this work, I have shared some projects as well as the related datasets, which I have done on Tableau Public.

# %% [markdown]
# # Project 1 : Titanic Dataset Analyzed and Visualized

# %% [markdown]
# The Titanic dataset on which i have used business intelligence tool (TABLEAU) to analyze the data and visualized as a dashboard.
# for this project i have use titanic dataset.
# Did Passengers Get Their Money's Worth?.
# *average fare for each class
# *The survival rate according to the fare.
# *average passenger fare by class

# %% [markdown]
# https://public.tableau.com/app/profile/swetha.murugesan5077/viz/Titanicdatasetanalysisvisualization/Dashboard1

# %%
from IPython.display import Image

Image("titanic representation.png")

# %% [markdown]
# # Project 2: Netflix movies and TV shows on countries analyzed and visualized

# %% [markdown]
# In this project, I have shown detailed information about the netflix movies and TV shows data on each country. I have chosen the "Netflix" dataset for this project. Please visit the link to see the Tableau project:

# %% [markdown]
# https://public.tableau.com/app/profile/swetha.murugesan5077/viz/NetflixmoviesandTVshowsoneachcountry/Dashboard1

# %%
Image("Netflix representation.png")

# %% [markdown]
# # Project 3: Air Pollution in 2022 and 2023 Analysis

# %% [markdown]
# In this project, I have shown detailed information about the air pollution in 2022 and 2023 data on each country. I have chosen the "Air Pollution" dataset for this project. Please visit the link to see the Tableau project:

# %% [markdown]
# https://public.tableau.com/app/profile/swetha.murugesan5077/viz/Airpollutionin2022and2023analysis/Dashboard1

# %%
Image("airpollution.png")

# %% [markdown]
# # Project 4: Bollywood movies according to its genre analysed the budget and revenue

# %% [markdown]
# In this project, I have shown detailed information about the Bollywood movies according to it genre analysed the budget and revenue data. I have chosen the "Bollywood" dataset for this project. Please visit the link to see the Tableau project:

# %% [markdown]
# https://public.tableau.com/app/profile/swetha.murugesan5077/viz/Bollywoodmoviesbudgetanditsrevenue/Dashboard1?publish=yes

# %%
Image("Bollywood.png")

# %% [markdown]
# # Project 5:  Tweet counts on weekdays

# %% [markdown]
# In this project, I have shown detailed information about the count of tweets according to the weekdays analysed the data. I have chosen the "twitterdata" dataset for this project. Please visit the link to see the Tableau project:

# %% [markdown]
# https://public.tableau.com/app/profile/swetha.murugesan5077/viz/twittercountsonweekdays/Dashboard1?publish=yes

# %%
Image("twitter.png")
